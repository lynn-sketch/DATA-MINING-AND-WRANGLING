# %% [markdown]
# ###importing the necessary packages

# %%
import  pandas as pd

# %%
#reading data from excel
##When working in the same directorate
student_data = pd.read_excel("Student_perfomance1.xlsx")

student_data.head()
# Out:
#   Access_No        Fname  Gender  Age  DSC3114  DSC3108  MTH3108  SYE3104
# 0    B21452         Lynn  Female   21       90       98       71       94
# 1    B23789     Emmanuel    Male   20       79      100       70       63
# 2    B18976      Leticia  Female   19       94       85       99       92
# 3    B12389  Christopher    Male   21       82       91       89       90
# 4    B23892      Noeline  Female   18       90       80       68       75

# %%
##From a different folder
bike_sales = pd.read_excel("C:/Users/HP PC/Desktop/BSDS 2_2/BIG DATA ANALYTICS/mydatasetsforpractice/cereal.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 ##From a different folder
# ----> 2 bike_sales = pd.read_excel("C:/Users/HP PC/Desktop/BSDS 2_2/BIG DATA ANALYTICS/mydatasetsforpractice/cereal.xlsx")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
# ...

# %%
student_data.head(10)
# Out:
#   Access_No        Fname  Gender  Age  DSC3114  DSC3108  MTH3108  SYE3104
# 0    B21452         Lynn  Female   21       90       98       71       94
# 1    B23789     Emmanuel    Male   20       79      100       70       63
# 2    B18976      Leticia  Female   19       94       85       99       92
# 3    B12389  Christopher    Male   21       82       91       89       90
# 4    B23892      Noeline  Female   18       90       80       68       75
# 5    B34589    Emmanuel     Male   22       75       94       73       92
# 6    B16980     Lorraine  Female   21       91       88       79       74
# 7    B12456        Anita  Female   21       79       95       92       60
# 8    B78909       Ronald    Male   19       98       86       64       83
# 9    B34098        Irwin    Male   18       84       97       71       91

# %%
#Describes only numerical data
student_data.describe()
# Out:
#              Age    DSC3114     DSC3108    MTH3108     SYE3104
# count  20.000000  20.000000   20.000000  20.000000   20.000000
# mean   20.100000  86.450000   91.950000  81.900000   79.400000
# std     1.333772   6.847781    5.216119  11.196334   15.308752
# min    18.000000  75.000000   80.000000  64.000000   54.000000
# 25%    19.000000  79.750000   88.750000  72.500000   65.500000
# 50%    20.000000  86.500000   92.500000  80.000000   79.000000
# 75%    21.000000  91.000000   95.250000  89.750000   92.250000
# max    22.000000  98.000000  100.000000  99.000000  100.000000

# %%
#describe including all data including categorical data
student_data.describe(include='all')
# Out:
#        Access_No Fname  Gender        Age    DSC3114     DSC3108    MTH3108  \
# count         20    20      20  20.000000  20.000000   20.000000  20.000000
# unique        20    20       2        NaN        NaN         NaN        NaN
# top       B21452  Lynn  Female        NaN        NaN         NaN        NaN
# freq           1     1      10        NaN        NaN         NaN        NaN
# mean         NaN   NaN     NaN  20.100000  86.450000   91.950000  81.900000
# std          NaN   NaN     NaN   1.333772   6.847781    5.216119  11.196334
# min          NaN   NaN     NaN  18.000000  75.000000   80.000000  64.000000
# 25%          NaN   NaN     NaN  19.000000  79.750000   88.750000  72.500000
# 50%          NaN   NaN     NaN  20.000000  86.500000   92.500000  80.000000
# 75%          NaN   NaN     NaN  21.000000  91.000000   95.250000  89.750000
# max          NaN   NaN     NaN  22.000000  98.000000  100.000000  99.000000
#
#            SYE3104
# count    20.000000
# ...

# %%
student_data.tail()
# Out:
#    Access_No     Fname  Gender  Age  DSC3114  DSC3108  MTH3108  SYE3104
# 15    B10098  Patience  Female   22       80       92       89       54
# 16    B90087     Jacob    Male   20       78       93       95       66
# 17    B20098     Enoch    Male   19       86       92       73       93
# 18    B90075     Peace  Female   21       86       92       97       64
# 19    B40034     Emily  Female   22       87       97       88      100

# %%
#Shows all values indicated
student_data.loc[3:7]
# Out:
#   Access_No        Fname  Gender  Age  DSC3114  DSC3108  MTH3108  SYE3104
# 3    B12389  Christopher    Male   21       82       91       89       90
# 4    B23892      Noeline  Female   18       90       80       68       75
# 5    B34589    Emmanuel     Male   22       75       94       73       92
# 6    B16980     Lorraine  Female   21       91       88       79       74
# 7    B12456        Anita  Female   21       79       95       92       60

# %%
#Shows all values excluding the last value
student_data.iloc[3:7]
# Out:
#   Access_No        Fname  Gender  Age  DSC3114  DSC3108  MTH3108  SYE3104
# 3    B12389  Christopher    Male   21       82       91       89       90
# 4    B23892      Noeline  Female   18       90       80       68       75
# 5    B34589    Emmanuel     Male   22       75       94       73       92
# 6    B16980     Lorraine  Female   21       91       88       79       74

# %%
#showing the datatypes
student_data.dtypes
# Out:
# Access_No    object
# Fname        object
# Gender       object
# Age           int64
# DSC3114       int64
# DSC3108       int64
# MTH3108       int64
# SYE3104       int64
# dtype: object

# %%
#showing the shape of the data
student_data.shape
# Out:
# (20, 8)

# %%
###EDA
###Missing values
-NAN, N/A, NULL

# %%
##Checking for missing values
missing_values = student_data.isnull().any()
missing_values
# Out:
# Access_No    False
# Fname        False
# Gender       False
# Age          False
# DSC3114      False
# DSC3108      False
# MTH3108      False
# SYE3104      False
# dtype: bool

# %%
##Checking for the sum of missing values
missing_values = student_data.isnull().sum()
missing_values
# Out:
# Access_No    0
# Fname        0
# Gender       0
# Age          0
# DSC3114      0
# DSC3108      0
# MTH3108      0
# SYE3104      0
# dtype: int64

# %% [markdown]
# ##Handling missing values
# -Dropping missing values
# -interporate
# -filling
# -imputation

# %% [markdown]
# ##Dropping missing values
# axis {0-row  1-column}

# %%
student_data
# Out:
#    Access_No        Fname  Gender  Age  DSC3114  DSC3108  MTH3108  SYE3104
# 0     B21452         Lynn  Female   21       90       98       71       94
# 1     B23789     Emmanuel    Male   20       79      100       70       63
# 2     B18976      Leticia  Female   19       94       85       99       92
# 3     B12389  Christopher    Male   21       82       91       89       90
# 4     B23892      Noeline  Female   18       90       80       68       75
# 5     B34589    Emmanuel     Male   22       75       94       73       92
# 6     B16980     Lorraine  Female   21       91       88       79       74
# 7     B12456        Anita  Female   21       79       95       92       60
# 8     B78909       Ronald    Male   19       98       86       64       83
# 9     B34098        Irwin    Male   18       84       97       71       91
# 10    B10978        Isaac    Male   21       97       89       74       99
# ...

# %%
##Dropping missing values
student_data.dropna(inplace=True)
student_data
# Out:
#    Access_No        Fname  Gender  Age  DSC3114  DSC3108  MTH3108  SYE3104
# 0     B21452         Lynn  Female   21       90       98       71       94
# 1     B23789     Emmanuel    Male   20       79      100       70       63
# 2     B18976      Leticia  Female   19       94       85       99       92
# 3     B12389  Christopher    Male   21       82       91       89       90
# 4     B23892      Noeline  Female   18       90       80       68       75
# 5     B34589    Emmanuel     Male   22       75       94       73       92
# 6     B16980     Lorraine  Female   21       91       88       79       74
# 7     B12456        Anita  Female   21       79       95       92       60
# 8     B78909       Ronald    Male   19       98       86       64       83
# 9     B34098        Irwin    Male   18       84       97       71       91
# 10    B10978        Isaac    Male   21       97       89       74       99
# ...

# %%
#when we use axis
student_data.dropna(axis=0, inplace= True) ##deleting rows with missing values
student_data.dropna(axis=1, inplace= True) ##deleting columns with missing values

# %%
#Assignment
#Make research on handling missing_values using  interpolate,filling and imputation using descriptive statistics
